# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

pre_treatment = pd.read_csv('data/Hoover_segment_pre2.csv')
post_treatment = pd.read_csv('data/Hoover_segment_post2.csv')

pre_filters = (pre_treatment['Day Type'] == '0: All Days (M-Su)') | (pre_treatment['Day Part'] == '0: All Day (12am-12am)')
post_filters = (post_treatment['Day Type'] == '0: All Days (M-Su)') | (post_treatment['Day Part'] == '0: All Day (12am-12am)')

pre_treatment = pre_treatment[~pre_filters]
post_treatment = post_treatment[~post_filters]

pre_speeds = pre_treatment['Avg Segment Speed (mph)']
post_speeds = post_treatment['Avg Segment Speed (mph)']
pre_volume = pre_treatment['Average Daily Segment Traffic (StL Volume)']
post_volume = post_treatment['Average Daily Segment Traffic (StL Volume)']

pre_weighted_speed = (pre_speeds * pre_volume).sum() / pre_volume.sum()
post_weighted_speed = (post_speeds * post_volume).sum() / post_volume.sum()

def weighted_std(values, weights):
    mean = (values * weights).sum() / weights.sum()
    variance = (weights * (values - mean) ** 2).sum() / weights.sum()
    return variance ** 0.5

pre_weighted_std = weighted_std(pre_speeds, pre_volume)
post_weighted_std = weighted_std(post_speeds, post_volume)
pre_weighted_se = weighted_std(pre_speeds, pre_volume) / (len(pre_speeds) ** 0.5)
post_weighted_se = weighted_std(post_speeds, post_volume) / (len(post_speeds) ** 0.5)

valid_indices = pre_speeds.notna() & post_speeds.notna()
t_stat, p_value = stats.ttest_rel(pre_speeds[valid_indices], post_speeds[valid_indices])

print(f"Weighted Pre-Treatment Speed: {pre_weighted_speed:.2f} mph")
print(f"Weighted Post-Treatment Speed: {post_weighted_speed:.2f} mph")
print(f"T-Statistic: {t_stat:.3f}, P-Value: {p_value:.3f}")

bar_colors = ['red', 'blue']
plt.figure(figsize=(6, 4))
plt.bar(['Pre-Treatment', 'Post-Treatment'], 
        [pre_weighted_speed, post_weighted_speed], 
        yerr=[pre_weighted_std, post_weighted_std], capsize=5, color=bar_colors)
plt.ylabel('Weighted Average Spot Speed (SD)')
plt.title('Traffic Circle: Pre vs Post-Treatment Speeds')
plt.show()

plt.figure(figsize=(6, 4))
plt.bar(['Pre-Treatment', 'Post-Treatment'], 
        [pre_weighted_speed, post_weighted_speed], 
        yerr=[pre_weighted_se, post_weighted_se], capsize=5, color=bar_colors)

plt.ylabel('Weighted Average Segment Speed (SE)')
plt.title('Traffic Circle: Pre vs Post-Treatment Segment Speeds')
plt.show()
# Out:
# Weighted Pre-Treatment Speed: 27.55 mph
# Weighted Post-Treatment Speed: 23.22 mph
# T-Statistic: 41.802, P-Value: 0.000

# %%
pre_weighted_85th_speed = (pre_treatment['85th Speed Percentile'] * pre_volume).sum() / pre_volume.sum()
post_weighted_85th_speed = (post_treatment['85th Speed Percentile'] * post_volume).sum() / post_volume.sum()

pre_weighted_95th_speed = (pre_treatment['95th Speed Percentile'] * pre_volume).sum() / pre_volume.sum()
post_weighted_95th_speed = (post_treatment['95th Speed Percentile'] * post_volume).sum() / post_volume.sum()

print(f"Weighted Pre-Treatment 85th Speed Percentile: {pre_weighted_85th_speed:.2f} mph")
print(f"Weighted Post-Treatment 85th Speed Percentile: {post_weighted_85th_speed:.2f} mph")
print(f"Weighted Pre-Treatment 95th Speed Percentile: {pre_weighted_95th_speed:.2f} mph")
print(f"Weighted Post-Treatment 95th Speed Percentile: {post_weighted_95th_speed:.2f} mph")
# Out:
# Weighted Pre-Treatment 85th Speed Percentile: 35.28 mph
# Weighted Post-Treatment 85th Speed Percentile: 30.84 mph
# Weighted Pre-Treatment 95th Speed Percentile: 38.97 mph
# Weighted Post-Treatment 95th Speed Percentile: 34.38 mph

# %%
max_85th_speed_row_pre = pre_treatment.loc[pre_treatment['85th Speed Percentile'].idxmax()]
max_85th_speed_row_post = post_treatment.loc[post_treatment['85th Speed Percentile'].idxmax()]

max_85th_speed_value_pre = max_85th_speed_row_pre['95th Speed Percentile']
max_85th_speed_value_post = max_85th_speed_row_post['95th Speed Percentile']

print(f"Highest value for pre-treatment'85th Speed Percentile': {max_85th_speed_value_pre} mph",
     f"Highest value for post-treatment'85th Speed Percentile': {max_85th_speed_value_post} mph")
print(max_85th_speed_row_pre,max_85th_speed_row_post )
top_speed = pre_treatment.sort_values('85th Speed Percentile', ascending = False).head(10)
top_speed
# Out:
# Highest value for pre-treatment'85th Speed Percentile': 42.0 mph Highest value for post-treatment'85th Speed Percentile': 38.0 mph
# Data Periods                                             Jan 01, 2022 - Dec 31, 2022
# Mode of Travel                                All Vehicles - StL All Vehicles Volume
# Zone ID                                                                          NaN
# Zone Name                                             South Hoover Street / 17167706
# Line Zone Length (Miles)                                                       0.301
# Zone Is Pass-Through                                                             yes
# Zone Direction (degrees)                                                         180
# Zone is Bi-Direction                                                             yes
# Year-Month                                                                   2022-01
# Day Type                                                             1: Monday (M-M)
# Day Part                                                      1: Early AM (12am-6am)
# Average Daily Segment Traffic (StL Volume)                                       285
# Avg Segment Speed (mph)                                                           31
# Avg Segment Travel Time (sec)                                                     36
# Free Flow Speed (mph)                                                         31.421
# Free Flow Factor                                                               0.972
# Vehicle Miles of Travel (StL Volume)                                           85.94
# Vehicle Hours of Delay (StL Volume)                                             0.08
# 5th Speed Percentile                                                            16.0
# 85th Speed Percentile                                                           38.0
# 95th Speed Percentile                                                           42.0
# Name: 7, dtype: object Data Periods                                             Jan 01, 2024 - Dec 31, 2024
# Mode of Travel                                All Vehicles - StL All Vehicles Volume
# Zone ID                                                                          NaN
# Zone Name                                             South Hoover Street / 17167706
# Line Zone Length (Miles)                                                       0.301
# Zone Is Pass-Through                                                             yes
# Zone Direction (degrees)                                                         180
# Zone is Bi-Direction                                                             yes
# Year-Month                                                                   2024-03
# Day Type                                                             1: Monday (M-M)
# Day Part                                                      1: Early AM (12am-6am)
# Average Daily Segment Traffic (StL Volume)                                       325
# Avg Segment Speed (mph)                                                           25
# Avg Segment Travel Time (sec)                                                     43
# Free Flow Speed (mph)                                                           25.9
# Free Flow Factor                                                               0.978
# Vehicle Miles of Travel (StL Volume)                                           98.09
# Vehicle Hours of Delay (StL Volume)                                             0.08
# 5th Speed Percentile                                                            12.0
# 85th Speed Percentile                                                           33.0
# 95th Speed Percentile                                                           38.0
# Name: 103, dtype: object
#                     Data Periods                          Mode of Travel  \
# 14   Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 8    Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 7    Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 332  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 272  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 260  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 20   Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 266  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 199  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 26   Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
#
#      Zone ID                       Zone Name  Line Zone Length (Miles)  \
# 14       NaN  South Hoover Street / 17167706                     0.301
# 8        NaN  South Hoover Street / 17167706                     0.301
# 7        NaN  South Hoover Street / 17167706                     0.301
# 332      NaN  South Hoover Street / 17167706                     0.301
# 272      NaN  South Hoover Street / 17167706                     0.301
# 260      NaN  South Hoover Street / 17167706                     0.301
# 20       NaN  South Hoover Street / 17167706                     0.301
# 266      NaN  South Hoover Street / 17167706                     0.301
# 199      NaN  South Hoover Street / 17167706                     0.301
# 26       NaN  South Hoover Street / 17167706                     0.301
#
#     Zone Is Pass-Through  Zone Direction (degrees) Zone is Bi-Direction  \
# 14                   yes                       180                  yes
# 8                    yes                       180                  yes
# 7                    yes                       180                  yes
# 332                  yes                       180                  yes
# 272                  yes                       180                  yes
# 260                  yes                       180                  yes
# 20                   yes                       180                  yes
# 266                  yes                       180                  yes
# 199                  yes                       180                  yes
# 26                   yes                       180                  yes
#
#     Year-Month             Day Type  ...  \
# 14     2022-01   2: Tuesday (Tu-Tu)  ...
# 8      2022-01      1: Monday (M-M)  ...
# 7      2022-01      1: Monday (M-M)  ...
# 332    2022-07    7: Sunday (Su-Su)  ...
# 272    2022-06      5: Friday (F-F)  ...
# 260    2022-06   3: Wednesday (W-W)  ...
# 20     2022-01   3: Wednesday (W-W)  ...
# 266    2022-06  4: Thursday (Th-Th)  ...
# 199    2022-05      1: Monday (M-M)  ...
# 26     2022-01  4: Thursday (Th-Th)  ...
#
#     Average Daily Segment Traffic (StL Volume)  Avg Segment Speed (mph)  \
# 14                                        1105                       30
# 8                                          974                       30
# 7                                          285                       31
# 332                                        363                       29
# 272                                       1091                       29
# 260                                       1167                       29
# 20                                        1052                       29
# 266                                       1126                       30
# 199                                        353                       30
# 26                                        1111                       29
#
#      Avg Segment Travel Time (sec)  Free Flow Speed (mph)  Free Flow Factor  \
# 14                              37                 31.421             0.941
# 8                               37                 31.421             0.943
# 7                               36                 31.421             0.972
# 332                             37                 30.143             0.970
# 272                             37                 31.281             0.936
# 260                             37                 31.281             0.938
# 20                              37                 31.421             0.933
# 266                             37                 31.281             0.947
# 199                             36                 30.792             0.983
# 26                              37                 31.421             0.937
#
#      Vehicle Miles of Travel (StL Volume)  \
# 14                                 333.06
# 8                                  293.66
# 7                                   85.94
# 332                                109.46
# 272                                328.94
# 260                                351.81
# 20                                 317.26
# 266                                339.35
# 199                                106.45
# 26                                 335.01
#
#      Vehicle Hours of Delay (StL Volume)  5th Speed Percentile  \
# 14                                  0.67                  13.0
# 8                                   0.56                  13.0
# 7                                   0.08                  16.0
# 332                                 0.11                  13.0
# 272                                 0.72                  13.0
# 260                                 0.74                  13.0
# 20                                  0.73                  13.0
# 266                                 0.60                  13.0
# 199                                 0.06                  15.0
# 26                                  0.72                  13.0
#
#      85th Speed Percentile  95th Speed Percentile
# 14                    38.0                   42.0
# 8                     38.0                   42.0
# 7                     38.0                   42.0
# 332                   38.0                   42.0
# 272                   38.0                   41.0
# 260                   38.0                   41.0
# 20                    38.0                   42.0
# 266                   38.0                   42.0
# 199                   38.0                   42.0
# 26                    38.0                   42.0
#
# [10 rows x 21 columns]

# %%
max_95th_speed_row_pre = pre_treatment.loc[pre_treatment['95th Speed Percentile'].idxmax()]
max_95th_speed_row_post = post_treatment.loc[post_treatment['95th Speed Percentile'].idxmax()]

max_95th_speed_value_pre = max_95th_speed_row_pre['95th Speed Percentile']
max_95th_speed_value_post = max_95th_speed_row_post['95th Speed Percentile']

print(f"Highest value for pre-treatment'95th Speed Percentile': {max_95th_speed_value_pre} mph",
     f"Highest value for post-treatment'95th Speed Percentile': {max_95th_speed_value_post} mph")
print(max_95th_speed_row_pre,max_95th_speed_row_post )
top_speed = pre_treatment.sort_values('95th Speed Percentile', ascending = False).head(10)
top_speed
# Out:
# Highest value for pre-treatment'95th Speed Percentile': 44.0 mph Highest value for post-treatment'95th Speed Percentile': 40.0 mph
# Data Periods                                             Jan 01, 2022 - Dec 31, 2022
# Mode of Travel                                All Vehicles - StL All Vehicles Volume
# Zone ID                                                                          NaN
# Zone Name                                             South Hoover Street / 17167706
# Line Zone Length (Miles)                                                       0.301
# Zone Is Pass-Through                                                             yes
# Zone Direction (degrees)                                                         180
# Zone is Bi-Direction                                                             yes
# Year-Month                                                                   2022-05
# Day Type                                                          2: Tuesday (Tu-Tu)
# Day Part                                                      1: Early AM (12am-6am)
# Average Daily Segment Traffic (StL Volume)                                       286
# Avg Segment Speed (mph)                                                           30
# Avg Segment Travel Time (sec)                                                     36
# Free Flow Speed (mph)                                                         30.792
# Free Flow Factor                                                               0.975
# Vehicle Miles of Travel (StL Volume)                                           86.21
# Vehicle Hours of Delay (StL Volume)                                             0.07
# 5th Speed Percentile                                                            14.0
# 85th Speed Percentile                                                           38.0
# 95th Speed Percentile                                                           44.0
# Name: 205, dtype: object Data Periods                                             Jan 01, 2024 - Dec 31, 2024
# Mode of Travel                                All Vehicles - StL All Vehicles Volume
# Zone ID                                                                          NaN
# Zone Name                                             South Hoover Street / 17167706
# Line Zone Length (Miles)                                                       0.301
# Zone Is Pass-Through                                                             yes
# Zone Direction (degrees)                                                         180
# Zone is Bi-Direction                                                             yes
# Year-Month                                                                   2024-08
# Day Type                                                             1: Monday (M-M)
# Day Part                                                      1: Early AM (12am-6am)
# Average Daily Segment Traffic (StL Volume)                                       502
# Avg Segment Speed (mph)                                                           26
# Avg Segment Travel Time (sec)                                                     42
# Free Flow Speed (mph)                                                         25.702
# Free Flow Factor                                                                 1.0
# Vehicle Miles of Travel (StL Volume)                                          151.29
# Vehicle Hours of Delay (StL Volume)                                              0.0
# 5th Speed Percentile                                                            13.0
# 85th Speed Percentile                                                           33.0
# 95th Speed Percentile                                                           40.0
# Name: 343, dtype: object
#                     Data Periods                          Mode of Travel  \
# 205  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 115  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 67   Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 151  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 61   Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 295  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 43   Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 253  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 80   Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
# 116  Jan 01, 2022 - Dec 31, 2022  All Vehicles - StL All Vehicles Volume
#
#      Zone ID                       Zone Name  Line Zone Length (Miles)  \
# 205      NaN  South Hoover Street / 17167706                     0.301
# 115      NaN  South Hoover Street / 17167706                     0.301
# 67       NaN  South Hoover Street / 17167706                     0.301
# 151      NaN  South Hoover Street / 17167706                     0.301
# 61       NaN  South Hoover Street / 17167706                     0.301
# 295      NaN  South Hoover Street / 17167706                     0.301
# 43       NaN  South Hoover Street / 17167706                     0.301
# 253      NaN  South Hoover Street / 17167706                     0.301
# 80       NaN  South Hoover Street / 17167706                     0.301
# 116      NaN  South Hoover Street / 17167706                     0.301
#
#     Zone Is Pass-Through  Zone Direction (degrees) Zone is Bi-Direction  \
# 205                  yes                       180                  yes
# 115                  yes                       180                  yes
# 67                   yes                       180                  yes
# 151                  yes                       180                  yes
# 61                   yes                       180                  yes
# 295                  yes                       180                  yes
# 43                   yes                       180                  yes
# 253                  yes                       180                  yes
# 80                   yes                       180                  yes
# 116                  yes                       180                  yes
#
#     Year-Month            Day Type  ...  \
# 205    2022-05  2: Tuesday (Tu-Tu)  ...
# 115    2022-03  3: Wednesday (W-W)  ...
# 67     2022-02  3: Wednesday (W-W)  ...
# 151    2022-04     1: Monday (M-M)  ...
# 61     2022-02  2: Tuesday (Tu-Tu)  ...
# 295    2022-07     1: Monday (M-M)  ...
# 43     2022-01   7: Sunday (Su-Su)  ...
# 253    2022-06  2: Tuesday (Tu-Tu)  ...
# 80     2022-02     5: Friday (F-F)  ...
# 116    2022-03  3: Wednesday (W-W)  ...
#
#     Average Daily Segment Traffic (StL Volume)  Avg Segment Speed (mph)  \
# 205                                        286                       30
# 115                                        279                       29
# 67                                         283                       31
# 151                                        337                       29
# 61                                         273                       30
# 295                                        426                       31
# 43                                         198                       30
# 253                                        270                       30
# 80                                        1226                       30
# 116                                       1327                       30
#
#      Avg Segment Travel Time (sec)  Free Flow Speed (mph)  Free Flow Factor  \
# 205                             36                 30.792             0.975
# 115                             37                 30.804             0.949
# 67                              36                 31.692             0.965
# 151                             37                 30.809             0.957
# 61                              36                 31.692             0.951
# 295                             35                 30.143             1.000
# 43                              36                 31.421             0.947
# 253                             36                 31.281             0.963
# 80                              37                 31.692             0.933
# 116                             37                 30.804             0.959
#
#      Vehicle Miles of Travel (StL Volume)  \
# 205                                 86.21
# 115                                 84.13
# 67                                  85.46
# 151                                101.47
# 61                                  82.29
# 295                                128.44
# 43                                  59.82
# 253                                 81.30
# 80                                 369.63
# 116                                399.97
#
#      Vehicle Hours of Delay (StL Volume)  5th Speed Percentile  \
# 205                                 0.07                  14.0
# 115                                 0.15                  14.0
# 67                                  0.10                  16.0
# 151                                 0.15                  14.0
# 61                                  0.13                  15.0
# 295                                 0.00                  16.0
# 43                                  0.11                  15.0
# 253                                 0.10                  16.0
# 80                                  0.83                  12.0
# 116                                 0.56                  13.0
#
#      85th Speed Percentile  95th Speed Percentile
# 205                   38.0                   44.0
# 115                   37.0                   43.0
# 67                    38.0                   43.0
# 151                   38.0                   43.0
# 61                    38.0                   43.0
# 295                   38.0                   43.0
# 43                    37.0                   43.0
# 253                   38.0                   43.0
# 80                    38.0                   42.0
# 116                   38.0                   42.0
#
# [10 rows x 21 columns]

# %%
filtered_pre = pre_treatment[pre_treatment['Day Type'] != '0: All Days (M-Su)']
filtered_post = post_treatment[post_treatment['Day Type'] != '0: All Days (M-Su)']

total_pre_volume = filtered_pre['Average Daily Segment Traffic (StL Volume)'].sum()
total_post_volume = filtered_post['Average Daily Segment Traffic (StL Volume)'].sum()

total_combined_volume = total_pre_volume + total_post_volume

print(f"Total Pre-Treatment Volume: {total_pre_volume:,.0f}")
print(f"Total Post-Treatment Volume: {total_post_volume:,.0f}")
print(f"Combined Volume (Pre + Post): {total_combined_volume:,.0f}")
# Out:
# Total Pre-Treatment Volume: 415,715
# Total Post-Treatment Volume: 416,978
# Combined Volume (Pre + Post): 832,693

# %%
results = {
    'Intersection': 'Hoover & 110th Pl',
'Pre_Mean': float(pre_weighted_speed),
    'Post_Mean': float(post_weighted_speed),
    'Pre_Std': float(pre_weighted_std),
    'Post_Std': float(post_weighted_std),
    'Pre_SE': float(pre_weighted_se),
    'Post_SE': float(post_weighted_se),
    'Pre_85th': float(pre_weighted_85th_speed),
    'Post_85th': float(post_weighted_85th_speed),
    'Pre_95th': float(pre_weighted_95th_speed),
    'Post_95th': float(post_weighted_95th_speed),
    'Pre_Max_85th': float(max_85th_speed_value_pre),
    'Post_Max_85th': float(max_85th_speed_value_post),
    'T_Statistic': float(t_stat),
    'P_Value': float(p_value),
    'Pre_Volume': int(total_pre_volume),
    'Post_Volume': int(total_post_volume),
    'Combined Volume': int(total_combined_volume),
    'Pre_Treatment_Volume': int(total_pre_volume),
    'Post_Treatment_Volume': int(total_post_volume),
    'Combined_Volumne': int(total_combined_volume)
}
import json
with open('../results/Hoover & 110th Pl_summary.json', 'w') as f:
    json.dump(results, f)
