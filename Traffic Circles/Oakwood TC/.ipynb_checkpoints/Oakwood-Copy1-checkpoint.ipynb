# %%
cd Oakwood TC
# Out:
# [Errno 2] No such file or directory: 'Oakwood TC'
# /home/jovyan/Capstone/Oakwood TC

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
pre_treatment = pd.read_csv('data/Oakwood_pre_treatment.csv')
post_treatment = pd.read_csv('data/Oakwood_post_treatment.csv')

# %%
pre_speeds = pre_treatment['Avg Spot Speed (mph)']
post_speeds = post_treatment['Avg Spot Speed (mph)']

t_stat, p_value = stats.ttest_rel(pre_speeds, post_speeds)

df = pd.DataFrame({
    'pre_speeds': pre_speeds,
    'post_speeds': post_speeds
})

summary_table = df.describe()
print(summary_table) 
bar_colors = ['red','blue']
plt.figure(figsize=(6, 4))
plt.bar(['Pre-Treatment', 'Post-Treatment'], 
        [pre_speeds.mean(), post_speeds.mean()], 
        yerr=[pre_speeds.std(), post_speeds.std()], capsize=5,color = bar_colors)

plt.ylabel('Average Spot Speed (mph)')
plt.title('Oakwood Traffic Circle: Pre vs Post-Treatment Speeds')
plt.show()
print(f"T-Statistic: {t_stat}")
print(f"P-Value: {p_value}")
# Out:
#         pre_speeds  post_speeds
# count  2304.000000  2304.000000
# mean     15.137153    15.084635
# std       2.696282     2.616665
# min       9.000000     8.000000
# 25%      13.000000    13.000000
# 50%      15.000000    15.000000
# 75%      17.000000    17.000000
# max      23.000000    22.000000
# T-Statistic: 2.914695279612311
# P-Value: 0.0035947153735084803

# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

pre_treatment = pd.read_csv('data/Oakwood_pre_treatment.csv')
post_treatment = pd.read_csv('data/Oakwood_post_treatment.csv')
filters = (pre_treatment['Day Type'] == '0: All Days (M-Su)') | (pre_treatment['Day Part'] == '0: All Day (12am-12am)')
pre_treatment = pre_treatment[~filters]
filters = (post_treatment['Day Type'] == '0: All Days (M-Su)') | (post_treatment['Day Part'] == '0: All Day (12am-12am)')
post_treatment = post_treatment[~filters]

pre_speeds = pre_treatment['Avg Spot Speed (mph)']
post_speeds = post_treatment['Avg Spot Speed (mph)']
pre_volume = pre_treatment['Average Daily Spot Traffic (StL Volume)']
post_volume = post_treatment['Average Daily Spot Traffic (StL Volume)']

pre_weighted_speed = (pre_speeds * pre_volume).sum() / pre_volume.sum()
post_weighted_speed = (post_speeds * post_volume).sum() / post_volume.sum()

df = pd.DataFrame({'pre_speeds': pre_speeds, 
                   'post_speeds': post_speeds})
summary_table = df.describe()
print(summary_table)

def weighted_std(values, weights):
    """Compute the weighted standard deviation."""
    mean = (values * weights).sum() / weights.sum()
    variance = (weights * (values - mean) ** 2).sum() / weights.sum()
    return variance ** 0.5

pre_weighted_std = weighted_std(pre_speeds, pre_volume)
post_weighted_std = weighted_std(post_speeds, post_volume)

valid_indices = pre_speeds.notna() & post_speeds.notna()
t_stat, p_value = stats.ttest_rel(pre_speeds[valid_indices], post_speeds[valid_indices])

print(f"Weighted Pre-Treatment Speed: {pre_weighted_speed:.2f} mph")
print(f"Weighted Post-Treatment Speed: {post_weighted_speed:.2f} mph")
print(f"T-Statistic: {t_stat:.3f}, P-Value: {p_value:.3f}")

bar_colors = ['red', 'blue']
plt.figure(figsize=(6, 4))
plt.bar(['Pre-Treatment', 'Post-Treatment'], 
        [pre_weighted_speed, post_weighted_speed], 
        yerr=[pre_weighted_std, post_weighted_std], capsize=5, color=bar_colors)

plt.ylabel('Weighted Average Spot Speed (mph)')
plt.title('Oakwood Traffic Circle: Pre vs Post-Treatment Speeds')
plt.show()
# Out:
#         pre_speeds  post_speeds
# count  1680.000000  1680.000000
# mean     15.266071    15.205357
# std       2.735955     2.653748
# min       9.000000     8.000000
# 25%      13.000000    13.750000
# 50%      15.000000    15.000000
# 75%      17.000000    17.000000
# max      23.000000    22.000000
# Weighted Pre-Treatment Speed: 14.22 mph
# Weighted Post-Treatment Speed: 14.11 mph
# T-Statistic: 2.635, P-Value: 0.008

# %%
filtered_pre = pre_treatment[pre_treatment['Day Type'] != '0: All Days (M-Su)']
filtered_post = post_treatment[post_treatment['Day Type'] != '0: All Days (M-Su)']

total_pre_volume = filtered_pre['Average Daily Spot Traffic (StL Volume)'].sum()
total_post_volume = filtered_post['Average Daily Spot Traffic (StL Volume)'].sum()

total_combined_volume = total_pre_volume + total_post_volume

print(f"Total Pre-Treatment Volume: {total_pre_volume:,.0f}")
print(f"Total Post-Treatment Volume: {total_post_volume:,.0f}")
print(f"Combined Volume (Pre + Post): {total_combined_volume:,.0f}")
# Out:
# Total Pre-Treatment Volume: 833,913
# Total Post-Treatment Volume: 804,416
# Combined Volume (Pre + Post): 1,638,329

# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

pre_treatment = pd.read_csv('data/Oakwood_pre_treatment.csv')
post_treatment = pd.read_csv('data/Oakwood_post_treatment.csv')

filters = (pre_treatment['Day Type'] == '0: All Days (M-Su)') | (pre_treatment['Day Part'] == '0: All Day (12am-12am)')
pre_treatment = pre_treatment[~filters]
filters = (post_treatment['Day Type'] == '0: All Days (M-Su)') | (post_treatment['Day Part'] == '0: All Day (12am-12am)')
post_treatment = post_treatment[~filters]

pre_speeds = pre_treatment['Avg Spot Speed (mph)']
post_speeds = post_treatment['Avg Spot Speed (mph)']
pre_volume = pre_treatment['Average Daily Spot Traffic (StL Volume)']
post_volume = post_treatment['Average Daily Spot Traffic (StL Volume)']

pre_weighted_speed = (pre_speeds * pre_volume).sum() / pre_volume.sum()
post_weighted_speed = (post_speeds * post_volume).sum() / post_volume.sum()

df = pd.DataFrame({'pre_speeds': pre_speeds, 
                   'post_speeds': post_speeds})
summary_table = df.describe()
print(summary_table)

def weighted_std(values, weights):
    """Compute the weighted standard deviation."""
    mean = (values * weights).sum() / weights.sum()
    variance = (weights * (values - mean) ** 2).sum() / weights.sum()
    return variance ** 0.5

pre_weighted_se = pre_weighted_std / (len(pre_speeds) ** 0.5)
post_weighted_se = post_weighted_std / (len(post_speeds) ** 0.5)


valid_indices = pre_speeds.notna() & post_speeds.notna()
t_stat, p_value = stats.ttest_rel(pre_speeds[valid_indices], post_speeds[valid_indices])

print(f"Weighted Pre-Treatment Speed: {pre_weighted_speed:.2f} mph")
print(f"Weighted Post-Treatment Speed: {post_weighted_speed:.2f} mph")
print(f"T-Statistic: {t_stat:.3f}, P-Value: {p_value:.3f}")

bar_colors = ['red', 'blue']
plt.figure(figsize=(6, 4))
plt.bar(['Pre-Treatment', 'Post-Treatment'], 
        [pre_weighted_speed, post_weighted_speed], 
        yerr=[pre_weighted_se, post_weighted_se], capsize=5, color=bar_colors)

plt.ylabel('Weighted Average Spot Speed (mph)')
plt.title('Oakwood Traffic Circle: Pre vs Post-Treatment Speeds')
plt.show()
# Out:
#         pre_speeds  post_speeds
# count  1680.000000  1680.000000
# mean     15.266071    15.205357
# std       2.735955     2.653748
# min       9.000000     8.000000
# 25%      13.000000    13.750000
# 50%      15.000000    15.000000
# 75%      17.000000    17.000000
# max      23.000000    22.000000
# Weighted Pre-Treatment Speed: 14.22 mph
# Weighted Post-Treatment Speed: 14.11 mph
# T-Statistic: 2.635, P-Value: 0.008

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# Load both datasets
pre_treatment = pd.read_csv('data/Oakwood_pre_treatment.csv')
post_treatment = pd.read_csv('data/Oakwood_post_treatment.csv')

# Filter out rows with unwanted 'Day Type' or 'Day Part' values
pre_filters = (pre_treatment['Day Type'] == '0: All Days (M-Su)') | (pre_treatment['Day Part'] == '0: All Day (12am-12am)')
post_filters = (post_treatment['Day Type'] == '0: All Days (M-Su)') | (post_treatment['Day Part'] == '0: All Day (12am-12am)')

pre_treatment = pre_treatment[~pre_filters]
post_treatment = post_treatment[~post_filters]

# Define a function to filter out outliers in a given column using z-scores
def filter_outliers(df, column, threshold=2):
    # Drop missing values from the column for z-score computation
    valid_values = df[column].dropna()
    z_scores = stats.zscore(valid_values)
    # Identify indices where the absolute z-score is below the threshold
    valid_indices = valid_values.index[np.abs(z_scores) < threshold]
    # Return only rows that meet the criterion
    return df.loc[valid_indices]

# Apply the filtering to both datasets on the "95th Speed Percentile" column
pre_treatment_filtered = filter_outliers(pre_treatment, '85th Speed Percentile')
post_treatment_filtered = filter_outliers(post_treatment, '85th Speed Percentile')

print("Pre-treatment data size before filtering:", pre_treatment.shape)
print("Pre-treatment data size after filtering:", pre_treatment_filtered.shape)
print("Post-treatment data size before filtering:", post_treatment.shape)
print("Post-treatment data size after filtering:", post_treatment_filtered.shape)

# Now perform your analysis on the filtered datasets
pre_speeds = pre_treatment_filtered['Avg Spot Speed (mph)']
post_speeds = post_treatment_filtered['Avg Spot Speed (mph)']
pre_volume = pre_treatment_filtered['Average Daily Spot Traffic (StL Volume)']
post_volume = post_treatment_filtered['Average Daily Spot Traffic (StL Volume)']

# Compute weighted average speeds
pre_weighted_speed = (pre_speeds * pre_volume).sum() / pre_volume.sum()
post_weighted_speed = (post_speeds * post_volume).sum() / post_volume.sum()

# Create a summary table
df = pd.DataFrame({'pre_speeds': pre_speeds, 'post_speeds': post_speeds})
summary_table = df.describe()
print(summary_table)

# Function to calculate weighted standard deviation
def weighted_std(values, weights):
    mean = (values * weights).sum() / weights.sum()
    variance = (weights * (values - mean) ** 2).sum() / weights.sum()
    return variance ** 0.5

pre_weighted_std = weighted_std(pre_speeds, pre_volume)
post_weighted_std = weighted_std(post_speeds, post_volume)

# For a paired t-test, ensure both datasets still align appropriately
valid_indices = pre_speeds.notna() & post_speeds.notna()
t_stat, p_value = stats.ttest_rel(pre_speeds[valid_indices], post_speeds[valid_indices])

print(f"Weighted Pre-Treatment Speed: {pre_weighted_speed:.2f} mph")
print(f"Weighted Post-Treatment Speed: {post_weighted_speed:.2f} mph")
print(f"T-Statistic: {t_stat:.3f}, P-Value: {p_value:.3f}")

# Plotting the results
bar_colors = ['red', 'blue']
plt.figure(figsize=(6, 4))
plt.bar(['Pre-Treatment', 'Post-Treatment'], 
        [pre_weighted_speed, post_weighted_speed], 
        yerr=[pre_weighted_std, post_weighted_std], capsize=5, color=bar_colors)
plt.ylabel('Weighted Average Spot Speed (mph)')
plt.title('Traffic Circle: Pre vs Post-Treatment Speeds')
plt.show()

max_85th_speed_row_pre = pre_treatment_filtered.loc[pre_treatment_filtered['85th Speed Percentile'].idxmax()]
max_85th_speed_row_post = post_treatment_filtered.loc[post_treatment_filtered['85th Speed Percentile'].idxmax()]

# Extract the highest value
max_85th_speed_value_pre = max_85th_speed_row_pre['85th Speed Percentile']
max_85th_speed_value_post = max_85th_speed_row_post['85th Speed Percentile']
# Display the result
print(f"Highest value for pre-treatment'85th Speed Percentile': {max_85th_speed_value_pre} mph",
     f"Highest value for post-treatment'85th Speed Percentile': {max_85th_speed_value_post} mph")
print("Row details:")
print(max_85th_speed_row_pre,max_85th_speed_row_post )
# Out:
# Pre-treatment data size before filtering: (1680, 17)
# Pre-treatment data size after filtering: (1622, 17)
# Post-treatment data size before filtering: (1680, 17)
# Post-treatment data size after filtering: (1594, 17)
#         pre_speeds  post_speeds
# count  1622.000000  1594.000000
# mean     15.200370    14.985571
# std       2.669761     2.469738
# min       9.000000     8.000000
# 25%      13.000000    13.000000
# 50%      15.000000    15.000000
# 75%      17.000000    17.000000
# max      21.000000    22.000000
# Weighted Pre-Treatment Speed: 14.20 mph
# Weighted Post-Treatment Speed: 14.03 mph
# T-Statistic: 3.365, P-Value: 0.001
# Highest value for pre-treatment'85th Speed Percentile': 27.0 mph Highest value for post-treatment'85th Speed Percentile': 26.0 mph
# Row details:
# Data Periods                                          Jun 01, 2021 - Jun 01, 2022
# Mode of Travel                             All Vehicles - StL All Vehicles Volume
# Zone ID                                                                       NaN
# Zone Name                                                            Oakwood East
# Zone Is Pass-Through                                                          yes
# Zone Direction (degrees)                                                      270
# Zone is Bi-Direction                                                          yes
# Year-Month                                                                2021-06
# Day Type                                                       3: Wednesday (W-W)
# Day Part                                                   1: Early AM (12am-6am)
# Average Daily Spot Traffic (StL Volume)                                        54
# Avg Spot Speed (mph)                                                           16
# Free Flow Speed (mph)                                                      19.161
# Free Flow Factor                                                            0.844
# 15th Speed Percentile                                                        12.0
# 85th Speed Percentile                                                        27.0
# 95th Speed Percentile                                                        29.0
# Name: 595, dtype: object Data Periods                                          Jun 01, 2022 - Jun 01, 2023
# Mode of Travel                             All Vehicles - StL All Vehicles Volume
# Zone ID                                                                       NaN
# Zone Name                                                   North Hayworth Avenue
# Zone Is Pass-Through                                                          yes
# Zone Direction (degrees)                                                        0
# Zone is Bi-Direction                                                          yes
# Year-Month                                                                2022-08
# Day Type                                                       2: Tuesday (Tu-Tu)
# Day Part                                                   1: Early AM (12am-6am)
# Average Daily Spot Traffic (StL Volume)                                        38
# Avg Spot Speed (mph)                                                           15
# Free Flow Speed (mph)                                                      19.501
# Free Flow Factor                                                            0.788
# 15th Speed Percentile                                                         5.0
# 85th Speed Percentile                                                        26.0
# 95th Speed Percentile                                                        31.0
# Name: 109, dtype: object

# %%
pre_filters = (pre_treatment['Day Type'] == '0: All Days (M-Su)') | (pre_treatment['Day Part'] == '0: All Day (12am-12am)')
post_filters = (post_treatment['Day Type'] == '0: All Days (M-Su)') | (post_treatment['Day Part'] == '0: All Day (12am-12am)')

pre_treatment = pre_treatment[~pre_filters]
post_treatment = post_treatment[~post_filters]

#def filter_outliers(df, column, threshold=3):
    #valid_values = df[column].dropna()
    #z_scores = stats.zscore(valid_values)
    #valid_indices = valid_values.index[np.abs(z_scores) < threshold]
    #return df.loc[valid_indices]

#pre_treatment_filtered = filter_outliers(pre_treatment, '95th Speed Percentile')
#post_treatment_filtered = filter_outliers(post_treatment, '95th Speed Percentile')

#print("Pre-treatment data size before filtering:", pre_treatment.shape)
#print("Pre-treatment data size after filtering:", pre_treatment_filtered.shape)
#print("Post-treatment data size before filtering:", post_treatment.shape)
#print("Post-treatment data size after filtering:", post_treatment_filtered.shape)

pre_speeds = pre_treatment_filtered['Avg Spot Speed (mph)']
post_speeds = post_treatment_filtered['Avg Spot Speed (mph)']
pre_volume = pre_treatment_filtered['Average Daily Spot Traffic (StL Volume)']
post_volume = post_treatment_filtered['Average Daily Spot Traffic (StL Volume)']

pre_weighted_speed = (pre_speeds * pre_volume).sum() / pre_volume.sum()
post_weighted_speed = (post_speeds * post_volume).sum() / post_volume.sum()

def weighted_std(values, weights):
    mean = (values * weights).sum() / weights.sum()
    variance = (weights * (values - mean) ** 2).sum() / weights.sum()
    return variance ** 0.5

pre_weighted_std = weighted_std(pre_speeds, pre_volume)
post_weighted_std = weighted_std(post_speeds, post_volume)
pre_weighted_se = weighted_std(pre_speeds, pre_volume) / (len(pre_speeds) ** 0.5)
post_weighted_se = weighted_std(post_speeds, post_volume) / (len(post_speeds) ** 0.5)

valid_indices = pre_speeds.notna() & post_speeds.notna()
t_stat, p_value = stats.ttest_rel(pre_speeds[valid_indices], post_speeds[valid_indices])

print(f"Weighted Pre-Treatment Speed: {pre_weighted_speed:.2f} mph")
print(f"Weighted Post-Treatment Speed: {post_weighted_speed:.2f} mph")
print(f"T-Statistic: {t_stat:.3f}, P-Value: {p_value:.3f}")

bar_colors = ['red', 'blue']
plt.figure(figsize=(6, 4))
plt.bar(['Pre-Treatment', 'Post-Treatment'], 
        [pre_weighted_speed, post_weighted_speed], 
        yerr=[pre_weighted_std, post_weighted_std], capsize=5, color=bar_colors)
plt.ylabel('Weighted Average Spot Speed (SD)')
plt.title('Traffic Circle: Pre vs Post-Treatment Speeds')
plt.show()

plt.figure(figsize=(6, 4))
plt.bar(['Pre-Treatment', 'Post-Treatment'], 
        [pre_weighted_speed, post_weighted_speed], 
        yerr=[pre_weighted_se, post_weighted_se], capsize=5, color=bar_colors)

plt.ylabel('Weighted Average Spot Speed (SE)')
plt.title('Traffic Circle: Pre vs Post-Treatment Speeds')
plt.show()

max_85th_speed_row_pre = pre_treatment.loc[pre_treatment['85th Speed Percentile'].idxmax()]
max_85th_speed_row_post = post_treatment.loc[post_treatment['85th Speed Percentile'].idxmax()]

max_85th_speed_value_pre = max_85th_speed_row_pre['85th Speed Percentile']
max_85th_speed_value_post = max_85th_speed_row_post['85th Speed Percentile']

print(f"Highest value for pre-treatment'85th Speed Percentile': {max_85th_speed_value_pre} mph",
     f"Highest value for post-treatment'85th Speed Percentile': {max_85th_speed_value_post} mph")
print("Row details:")
print(max_85th_speed_row_pre,max_85th_speed_row_post )
top_speed = pre_treatment.sort_values('95th Speed Percentile', ascending = False).head(10)
top_speed
# Out:
# Weighted Pre-Treatment Speed: 14.20 mph
# Weighted Post-Treatment Speed: 14.03 mph
# T-Statistic: 3.365, P-Value: 0.001
# Highest value for pre-treatment'85th Speed Percentile': 35.0 mph Highest value for post-treatment'85th Speed Percentile': 33.0 mph
# Row details:
# Data Periods                                          Jun 01, 2021 - Jun 01, 2022
# Mode of Travel                             All Vehicles - StL All Vehicles Volume
# Zone ID                                                                       NaN
# Zone Name                                                   North Hayworth Avenue
# Zone Is Pass-Through                                                          yes
# Zone Direction (degrees)                                                        0
# Zone is Bi-Direction                                                          yes
# Year-Month                                                                2021-10
# Day Type                                                          1: Monday (M-M)
# Day Part                                                   1: Early AM (12am-6am)
# Average Daily Spot Traffic (StL Volume)                                        38
# Avg Spot Speed (mph)                                                           17
# Free Flow Speed (mph)                                                      21.708
# Free Flow Factor                                                            0.784
# 15th Speed Percentile                                                         3.0
# 85th Speed Percentile                                                        35.0
# 95th Speed Percentile                                                        52.0
# Name: 199, dtype: object Data Periods                                          Jun 01, 2022 - Jun 01, 2023
# Mode of Travel                             All Vehicles - StL All Vehicles Volume
# Zone ID                                                                       NaN
# Zone Name                                               South Hayworth Avenue (1)
# Zone Is Pass-Through                                                          yes
# Zone Direction (degrees)                                                        0
# Zone is Bi-Direction                                                          yes
# Year-Month                                                                2022-09
# Day Type                                                       2: Tuesday (Tu-Tu)
# Day Part                                                   1: Early AM (12am-6am)
# Average Daily Spot Traffic (StL Volume)                                        31
# Avg Spot Speed (mph)                                                           19
# Free Flow Speed (mph)                                                      24.682
# Free Flow Factor                                                            0.772
# 15th Speed Percentile                                                        14.0
# 85th Speed Percentile                                                        33.0
# 95th Speed Percentile                                                        33.0
# Name: 1885, dtype: object
#                      Data Periods                          Mode of Travel  \
# 199   Jun 01, 2021 - Jun 01, 2022  All Vehicles - StL All Vehicles Volume
# 2029  Jun 01, 2021 - Jun 01, 2022  All Vehicles - StL All Vehicles Volume
# 2137  Jun 01, 2021 - Jun 01, 2022  All Vehicles - StL All Vehicles Volume
# 2089  Jun 01, 2021 - Jun 01, 2022  All Vehicles - StL All Vehicles Volume
# 265   Jun 01, 2021 - Jun 01, 2022  All Vehicles - StL All Vehicles Volume
# 601   Jun 01, 2021 - Jun 01, 2022  All Vehicles - StL All Vehicles Volume
# 589   Jun 01, 2021 - Jun 01, 2022  All Vehicles - StL All Vehicles Volume
# 1759  Jun 01, 2021 - Jun 01, 2022  All Vehicles - StL All Vehicles Volume
# 205   Jun 01, 2021 - Jun 01, 2022  All Vehicles - StL All Vehicles Volume
# 2179  Jun 01, 2021 - Jun 01, 2022  All Vehicles - StL All Vehicles Volume
#
#       Zone ID                  Zone Name Zone Is Pass-Through  \
# 199       NaN      North Hayworth Avenue                  yes
# 2029      NaN  South Hayworth Avenue (1)                  yes
# 2137      NaN  South Hayworth Avenue (1)                  yes
# 2089      NaN  South Hayworth Avenue (1)                  yes
# 265       NaN      North Hayworth Avenue                  yes
# 601       NaN               Oakwood East                  yes
# 589       NaN               Oakwood East                  yes
# 1759      NaN  South Hayworth Avenue (1)                  yes
# 205       NaN      North Hayworth Avenue                  yes
# 2179      NaN  South Hayworth Avenue (1)                  yes
#
#       Zone Direction (degrees) Zone is Bi-Direction Year-Month  \
# 199                          0                  yes    2021-10
# 2029                         0                  yes    2021-12
# 2137                         0                  yes    2022-02
# 2089                         0                  yes    2022-01
# 265                          0                  yes    2021-11
# 601                        270                  yes    2021-06
# 589                        270                  yes    2021-06
# 1759                         0                  yes    2021-06
# 205                          0                  yes    2021-10
# 2179                         0                  yes    2022-03
#
#                  Day Type                Day Part  \
# 199       1: Monday (M-M)  1: Early AM (12am-6am)
# 2029   2: Tuesday (Tu-Tu)  1: Early AM (12am-6am)
# 2137  4: Thursday (Th-Th)  1: Early AM (12am-6am)
# 2089  4: Thursday (Th-Th)  1: Early AM (12am-6am)
# 265   4: Thursday (Th-Th)  1: Early AM (12am-6am)
# 601   4: Thursday (Th-Th)  1: Early AM (12am-6am)
# 589    2: Tuesday (Tu-Tu)  1: Early AM (12am-6am)
# 1759      5: Friday (F-F)  1: Early AM (12am-6am)
# 205    2: Tuesday (Tu-Tu)  1: Early AM (12am-6am)
# 2179   3: Wednesday (W-W)  1: Early AM (12am-6am)
#
#       Average Daily Spot Traffic (StL Volume)  Avg Spot Speed (mph)  \
# 199                                        38                    17
# 2029                                       33                    22
# 2137                                       49                    21
# 2089                                       41                    19
# 265                                        40                    15
# 601                                        57                    16
# 589                                        46                    16
# 1759                                       88                    22
# 205                                        39                    17
# 2179                                       52                    21
#
#       Free Flow Speed (mph)  Free Flow Factor  15th Speed Percentile  \
# 199                  21.708             0.784                    3.0
# 2029                 27.055             0.826                   15.0
# 2137                 24.139             0.852                   10.0
# 2089                 25.903             0.741                   13.0
# 265                  18.648             0.814                    3.0
# 601                  19.161             0.843                   11.0
# 589                  19.161             0.854                    7.0
# 1759                 24.833             0.880                   16.0
# 205                  21.708             0.779                   13.0
# 2179                 24.873             0.831                   16.0
#
#       85th Speed Percentile  95th Speed Percentile
# 199                    35.0                   52.0
# 2029                   29.0                   47.0
# 2137                   28.0                   43.0
# 2089                   27.0                   42.0
# 265                    19.0                   38.0
# 601                    21.0                   38.0
# 589                    24.0                   36.0
# 1759                   28.0                   36.0
# 205                    21.0                   36.0
# 2179                   27.0                   35.0

# %%
pre_weighted_85th_speed = (pre_treatment['85th Speed Percentile'] * pre_volume).sum() / pre_volume.sum()
post_weighted_85th_speed = (post_treatment['85th Speed Percentile'] * post_volume).sum() / post_volume.sum()

pre_weighted_95th_speed = (pre_treatment['95th Speed Percentile'] * pre_volume).sum() / pre_volume.sum()
post_weighted_95th_speed = (post_treatment['95th Speed Percentile'] * post_volume).sum() / post_volume.sum()

print(f"Weighted Pre-Treatment 85th Speed Percentile: {pre_weighted_85th_speed:.2f} mph")
print(f"Weighted Post-Treatment 85th Speed Percentile: {post_weighted_85th_speed:.2f} mph")
print(f"Weighted Pre-Treatment 95th Speed Percentile: {pre_weighted_95th_speed:.2f} mph")
print(f"Weighted Post-Treatment 95th Speed Percentile: {post_weighted_95th_speed:.2f} mph")
# Out:
# Weighted Pre-Treatment 85th Speed Percentile: 19.27 mph
# Weighted Post-Treatment 85th Speed Percentile: 19.10 mph
# Weighted Pre-Treatment 95th Speed Percentile: 24.27 mph
# Weighted Post-Treatment 95th Speed Percentile: 24.01 mph
