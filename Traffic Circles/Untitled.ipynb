# %%
import os
import json
import pandas as pd

# Define the directory containing the JSON summary files
summary_dir = 'results'
data = []

# Loop through each file and extract relevant information
for filename in os.listdir(summary_dir):
    if filename.endswith('_summary.json'):
        filepath = os.path.join(summary_dir, filename)
        with open(filepath, 'r') as file:
            record = json.load(file)
            data.append({
                'Intersection': record.get('Intersection'),
                'Pre_Mean': record.get('Pre_Mean'),
                'Post_Mean': record.get('Post_Mean'),
                'Pre_Std': record.get('Pre_Std'),
                'Post_Std': record.get('Post_Std'),
                'Pre_SE': record.get('Pre_SE'),
                'Post_SE': record.get('Post_SE'),
                'Pre_85th': record.get('Pre_85th'),
                'Post_85th': record.get('Post_85th'),
                'Pre_95th': record.get('Pre_95th'),
                'Post_95th': record.get('Post_95th'),
                'Pre_Max_85th': record.get('Pre_Max_85th'),
                'Post_Max_85th': record.get('Post_Max_85th'),
                'T_Statistic': record.get('T_Statistic'),
                'P_Value': record.get('P_Value'),
                'Pre_Volume': record.get('Pre_Volume'),
                'Post_Volume': record.get('Post_Volume'),
                'Combined Volume': record.get('Combined Volume') or record.get('Combined_Volumne')
            })

# Convert to DataFrame
df = pd.DataFrame(data)
df.loc['Total'] = [''] * (df.shape[1] - 1) + [df.iloc[:, -1].sum()]
df['Type'] = 'Traffic Circle'

cols = df.columns.tolist()
# Move 'Type' from its current position
cols.insert(1, cols.pop(cols.index('Type')))
df.loc['Total', 'Type'] = ''
df = df[cols]

# Display the DataFrame to the user
#import ace_tools as tools; tools.display_dataframe_to_user(name="Intersection Treatment Results", dataframe=df)

# %%
df.head(20)
# Out:
#                      Intersection            Type   Pre_Mean  Post_Mean  \
# 0       Nebraska Ave & Purdue Ave  Traffic Circle   16.02877  15.075388
# 1      Ellenwood Dr & Addison Way  Traffic Circle  18.766212  15.303957
# 2          Woodlawn Ave & 41st Pl  Traffic Circle  16.962372  15.683186
# 3           5th Ave & 30th Street  Traffic Circle  17.968129  16.776646
# 4       Rosewood Ave & Martel Ave  Traffic Circle  15.960321  15.414132
# 5              St Andrews Pl 31st  Traffic Circle  17.130275  16.095266
# 6                 Neptune & G Ave  Traffic Circle  15.981633  14.919834
# 7      Oakwood Ave & Hayworth Ave  Traffic Circle  14.200453  14.034472
# 8                 Neptune & F Ave  Traffic Circle  16.859289  15.754037
# 9           Cimarron St & 29th St  Traffic Circle  16.908614   16.05147
# 10       Texas Ave & Westgate Ave  Traffic Circle  13.928611  13.555287
# 11       Romaine St & Serrano Ave  Traffic Circle  15.260357  13.893222
# 12        Avenue 50 & Meridian St  Traffic Circle  16.375895  14.129798
# 13          St Andrews Pl 29th St  Traffic Circle  16.653286  15.925465
# 14      McKinley Ave & E. 88th Pl  Traffic Circle  16.905293  15.920569
# 15        Buchanan St & Nolden St  Traffic Circle  16.206961  15.035572
# 16             Cimarron & 39th St  Traffic Circle  16.589784  15.686532
# Total
#
#         Pre_Std  Post_Std    Pre_SE   Post_SE   Pre_85th  Post_85th  \
